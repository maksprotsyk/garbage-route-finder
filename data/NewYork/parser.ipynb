# %%
import pandas as pd

def create_containers(filename, container_type):
    df = pd.read_csv(filename)
    df.head()

    containers = []
    for row in df.iterrows():
        latitude = row[1]["Latitude"]
        longitude = row[1]["Longitude"]
        if str(latitude) == "nan":
            continue
        containers.append(
            {
                "type": container_type,
                "latitude": float(latitude),
                "longitude": float(longitude),
                "start": 0,
                "finish": 100000000
            }
        )    
    return containers

containers = create_containers("nyc.csv", "RegularContainer")
types = ["mixed"]
container_names = ["RegularContainer"]
containers
# Out:
# [{'type': 'RegularContainer',
#   'latitude': 40.890848989,
#   'longitude': -73.864223918,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.8488907878,
#   'longitude': -73.8771283938,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.85557,
#   'longitude': -73.88756499999998,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.871864,
#   'longitude': -73.805549,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.851889,
#   'longitude': -73.868549,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.861526,
#   'longitude': -73.88065899999998,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.860755,
#   'longitude': -73.88042299999998,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.859644,
#   'longitude': -73.88047199999998,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.862602,
#   'longitude': -73.880171,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.826939,
#   'longitude': -73.922314,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.826627,
#   'longitude': -73.922447,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.854322,
#   'longitude': -73.869764,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.854445,
#   'longitude': -73.869863,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.84976,
#   'longitude': -73.880055,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.850017,
#   'longitude': -73.880035,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.819933,
#   'longitude': -73.887069,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.871706,
#   'longitude': -73.872741,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.911295,
#   'longitude': -73.907652,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.911236,
#   'longitude': -73.90791,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.825217,
#   'longitude': -73.88546,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.840115,
#   'longitude': -73.895513,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.835226,
#   'longitude': -73.895652,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.84133,
#   'longitude': -73.892702,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.840876,
#   'longitude': -73.898206,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.838351,
#   'longitude': -73.893566,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.841123,
#   'longitude': -73.898056,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.83377,
#   'longitude': -73.877453,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.841444,
#   'longitude': -73.888487,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.875553,
#   'longitude': -73.86052599999998,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.833109,
#   'longitude': -73.82828499999998,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.85042,
#   'longitude': -73.915529,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.849292,
#   'longitude': -73.902175,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.822893,
#   'longitude': -73.91266,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.813663,
#   'longitude': -73.905898,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.82201,
#   'longitude': -73.914009,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.862402,
#   'longitude': -73.897174,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.861379,
#   'longitude': -73.881414,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.861267,
#   'longitude': -73.89014,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.861948,
#   'longitude': -73.893726,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.869996,
#   'longitude': -73.876238,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.847026,
#   'longitude': -73.882534,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.816171,
#   'longitude': -73.917594,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.814213,
#   'longitude': -73.885886,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.814213,
#   'longitude': -73.885886,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.817471,
#   'longitude': -73.882622,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.81484,
#   'longitude': -73.90691,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.858005,
#   'longitude': -73.90485,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.829632,
#   'longitude': -73.921933,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.827502,
#   'longitude': -73.923062,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.877667,
#   'longitude': -73.90062,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.835694,
#   'longitude': -73.925664,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.8229705286,
#   'longitude': -73.9128832182,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.8229923969,
#   'longitude': -73.9318925429,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.834258,
#   'longitude': -73.923392,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.831466,
#   'longitude': -73.923947,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.8415557191,
#   'longitude': -73.8775226739,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.822711,
#   'longitude': -73.890242,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.889428,
#   'longitude': -73.864356,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.836706,
#   'longitude': -73.872355,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.90208,
#   'longitude': -73.868519,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.884079,
#   'longitude': -73.866996,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.866292,
#   'longitude': -73.794774,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.867984,
#   'longitude': -73.793396,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.868802,
#   'longitude': -73.792261,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.869068,
#   'longitude': -73.792558,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.872275,
#   'longitude': -73.797323,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.840504,
#   'longitude': -73.842668,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.840626,
#   'longitude': -73.843231,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.82366,
#   'longitude': -73.850766,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.838797,
#   'longitude': -73.845791,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40

#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.535174,
#   'longitude': -74.210125,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.557382,
#   'longitude': -74.10392,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.560272,
#   'longitude': -74.10104,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.620135,
#   'longitude': -74.118801,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.618744,
#   'longitude': -74.118278,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.613891,
#   'longitude': -74.113523,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.637872,
#   'longitude': -74.118791,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.614615,
#   'longitude': -74.07412,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.640999,
#   'longitude': -74.135418,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.6200556871,
#   'longitude': -74.1631154874,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.588496,
#   'longitude': -74.138918,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.584516,
#   'longitude': -74.12503499999998,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.593686,
#   'longitude': -74.135646,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.564469,
#   'longitude': -74.097531,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.637596,
#   'longitude': -74.074802,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.585877,
#   'longitude': -74.100975,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.643368,
#   'longitude': -74.086066,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.575019,
#   'longitude': -74.098706,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.57669,
#   'longitude': -74.098663,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.628859,
#   'longitude': -74.118013,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.627186,
#   'longitude': -74.091985,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.628358,
#   'longitude': -74.099058,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.579313,
#   'longitude': -74.07768799999998,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.642709,
#   'longitude': -74.07572399999998,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.642324,
#   'longitude': -74.075489,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.642303,
#   'longitude': -74.076549,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.505646,
#   'longitude': -74.235477,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.643799,
#   'longitude': -74.108845,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.642843,
#   'longitude': -74.11032,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.643449,
#   'longitude': -74.11046,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.643343,
#   'longitude': -74.108641,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.637121,
#   'longitude': -74.119287,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.603832,
#   'longitude': -74.158697,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.603828,
#   'longitude': -74.16125,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.517368,
#   'longitude': -74.190913,
#   'start': 0,
#   'finish': 100000000},
#  {'type': 'RegularContainer',
#   'latitude': 40.518652,
#   'longitude': -74.18730999999998,
#   'start': 0,
#   'finish': 100000000}]

# %%
len(containers)
# Out:
# 544

# %%
import random
random.seed(0)

def get_random_location(containers):
    index = random.randrange(0, len(containers) - 1)
    res = containers[index]["latitude"], containers[index]["longitude"]
    del containers[index]
    return res
trucks_location = get_random_location(containers)
landfill_location = (40.5656382, -74.1940109)

# %%
import json
truck_types = [
    {
      "type": "RegulaTruck",
      "speed": 150,
      "fuel_consumption": 7,
      "fuel_capacity": 150,
      "capacities": {"mixed": 100},
      "unloading_time": 15
    },
    {
      "type": "BigTruck",
      "speed": 10,
      "fuel_consumption": 0.5,
      "fuel_capacity": 50000,
      "capacities": {"mixed": 200},
      "unloading_time": 15
    },
]


container_types = [
    {
        "capacity": 10,
        "processing_time": 10,
        "garbage_type": types[i],
        "type": container_names[i]
    }
    
    for i in range(len(types))
]

trucks = []
for i in range(10):
        trucks.append(
            {
                "type": "BigTruck",
                "latitude": trucks_location[0],
                "longitude": trucks_location[1],
                "start": 0,
                "finish": 100000000
            }
        )
landfills = [
    {
        "latitude": landfill_location[0],
        "longitude": landfill_location[1],
        "start": 0,
        "finish": 100000000,
        "max_trucks": 100
    }
]
data = {"containers": containers, "description": "NewYork", "trucks": trucks, "landfills": landfills}
json_string = json.dumps(data, indent=4)
with open("input.json", "w") as f:
    f.write(json_string)

# %%
config_data = {
    "garbage_types": types,
    "container_types": container_types,
    "truck_types": truck_types
}
json_string = json.dumps(config_data, indent=4)
with open("config.json", "w") as f:
    f.write(json_string)

# %%
print(truck_types)
# Out:
# [{'type': 'RegulaTruck', 'speed': 150, 'fuel_consumption': 7, 'fuel_capacity': 150, 'capacities': {'mixed': 100}, 'unloading_time': 15}, {'type': 'BigTruck', 'speed': 10, 'fuel_consumption': 0.5, 'fuel_capacity': 50000, 'capacities': {'mixed': 200}, 'unloading_time': 15}]
