# %%
import json
import folium
import folium.plugins
import random
import sys
from pyproj import Geod

COLORS = [
    'red', 'blue', 'green', 'purple', 'orange', 'darkred',
    'darkblue', 'darkgreen', 'cadetblue',
    'darkpurple', 'white', 'pink',
    'gray', 'black'
    ]

def delta(val=0.001):
    return random.random() * val - val/2

def get_trucks_group(json_data, marker_func):
    group = folium.FeatureGroup(name="Trucks")
    trucks = json_data["Trucks"]
    colors = {}
    for truck in trucks:
        lat = float(truck["Latitude"])
        lon = float(truck["Longitude"])
        type_name = truck["Type"]
        colors[type_name] = colors.get(type_name, COLORS[len(colors)])
        group.add_child(marker_func(lat, lon, type_name, colors[type_name]))
    return group

def get_containers_group(json_data, marker_func):
    group = folium.FeatureGroup(name="Containers")
    containers = json_data["Containers"]
    colors = {}
    for container in containers:
        lat = float(container["Latitude"])
        lon = float(container["Longitude"])
        type_name = container["Type"]
        colors[type_name] = colors.get(type_name, COLORS[len(colors)])
        group.add_child(marker_func(lat, lon, type_name, colors[type_name]))
    return group

def get_landfills_group(json_data, marker_func):
    group = folium.FeatureGroup(name="Landfills")
    lanfills = json_data["Landfills"]
    colors = {}
    for landfill in lanfills:
        lat = float(landfill["Latitude"])
        lon = float(landfill["Longitude"])
        type_name = "Lanfill"
        colors[type_name] = colors.get(type_name, COLORS[len(colors)])
        group.add_child(marker_func(lat, lon, type_name, colors[type_name]))
    return group


def truck_marker(lat, long, type_name, color):
    return folium.Marker(
        location=(lat + delta(), long + delta()),
        tooltip=type_name,
        icon=folium.Icon(color=color, icon='truck', prefix='fa')
        )

def container_marker(lat, long, type_name, color):
    return folium.CircleMarker(
        location=(lat, long),
        tooltip=type_name,
        radius=4,
        color=color
        )

def landfill_marker(lat, long, type_name, color):
    return folium.Marker(
        location=(lat + delta(), long + delta()),
        tooltip=type_name,
        icon=folium.Icon(color=color, icon='recycle', prefix='fa')
        )

def get_routes(json_data):
    route_groups = []
    geodesic = Geod(ellps='WGS84')
    routes = json_data["Routes"]
    for i, route in enumerate(routes):
        color = COLORS[i % len(COLORS)]
        group = folium.FeatureGroup(name=f"Route {i+1} ({color})")
        route_groups.append(group)
        locations = [(point["Latitude"], point["Longitude"]) for point in route["Points"]]
        route_points = folium.PolyLine(
                locations=locations, 
                weight=2,
                color=color
        )
        group.add_child(route_points)
        for j in range(1, len(locations)):
                if ((locations[j][1] - locations[j-1][1]) ** 2 + (locations[j][0] - locations[j-1][0]) ** 2) ** 0.5 < 0.00001:
                    continue
                rotation = geodesic.inv(locations[j][1], locations[j][0], locations[j-1][1], locations[j-1][0])[0] + 90

                loc = [
                    (locations[j][0] + locations[j-1][0]) / 2,
                    (locations[j][1] + locations[j-1][1]) / 2
                    ]

                triangle = folium.RegularPolygonMarker(
                    color=color,
                    fill=True,
                    fillcolor=color,
                    location=loc,
                    number_of_sides=3,
                    radius=5,
                    rotation=rotation
                    )
                group.add_child(triangle)
        route_groups.append(group)
    return route_groups



def create_map(json_file, output):
    with open(json_file) as f:
        data = json.load(f)
        
    lat = sum([cont["Latitude"] for cont in data["Containers"]]) / len(data["Containers"])       
    lon = sum([cont["Longitude"] for cont in data["Containers"]]) / len(data["Containers"])
    map_obj = folium.Map(location=(lat, lon), zoom_start=11)

    map_obj.add_child(get_trucks_group(data, marker_func=truck_marker))
    map_obj.add_child(get_containers_group(data, marker_func=container_marker))
    map_obj.add_child(get_landfills_group(data, marker_func=landfill_marker))
    for route_group in get_routes(data):
        map_obj.add_child(route_group)
    map_obj.add_child(folium.map.LayerControl('topleft', collapsed=False))

    loc = f'Total cost: {data["TotalDistance"]}'
    title_html = f'''
                 <h3 align="center" style="font-size:16px"><b>{loc}</b></h3>
                 '''

    map_obj.get_root().html.add_child(folium.Element(title_html))

    map_obj.save(output)

# %%
import os

PROGRAM_PATH = "./smit-opt"

def run(params):
    args = [f"--{name}={value}" for name, value in params.items()]
    command = f"{PROGRAM_PATH} {' '.join(args)}"
    res = os.system(command)
    if res != 0:
        print("ERROR")
        print("Command:", command)
        print("RES:", res)
        
params = {
    "input": "data/Amsterdam/input.json",
    "config": "data/Amsterdam/config.json",
    "output": "data/Amsterdam/output.json",
    "real": True,
    "map_file": "data/Amsterdam/osrm/netherlands-latest.osrm",
    "search": "TABU"
}

# %%
run(params)
# Out:
# ERROR
# Command: ./smit-opt --input=data/Amsterdam/input.json --config=data/Amsterdam/config.json --output=data/Amsterdam/output.json --real=True --map_file=data/Amsterdam/osrm/netherlands-latest.osrm --search=TABU
# RES: 2

# %%
create_map("results_lviv/output_0.json", "test.html")

# %%
with open("lviv_results/output_10.json") as f:
    data = json.load(f)
data
# Out:
# {'BaseSolution': 'CLUSTER',
#  'Containers': [{'Latitude': 49.80594253540039,
#    'Longitude': 23.988576889038086,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8032341003418,
#    'Longitude': 23.996932983398438,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.803958892822266,
#    'Longitude': 23.996965408325195,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80763626098633,
#    'Longitude': 23.990509033203125,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80380630493164,
#    'Longitude': 23.9984073638916,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.799415588378906,
#    'Longitude': 24.014829635620117,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.827354431152344,
#    'Longitude': 24.00619125366211,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80091857910156,
#    'Longitude': 23.987136840820312,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.802711486816406,
#    'Longitude': 23.98552703857422,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.77351379394531,
#    'Longitude': 24.0100040435791,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82967758178711,
#    'Longitude': 24.007457733154297,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81082534790039,
#    'Longitude': 23.992570877075195,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81071853637695,
#    'Longitude': 23.991138458251953,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81052780151367,
#    'Longitude': 23.99382781982422,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81061935424805,
#    'Longitude': 23.99303436279297,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.810874938964844,
#    'Longitude': 23.99814224243164,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.836143493652344,
#    'Longitude': 24.00128173828125,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.83320999145508,
#    'Longitude': 24.009765625,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.809364318847656,
#    'Longitude': 23.99813461303711,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.799224853515625,
#    'Longitude': 23.996082305908203,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82339859008789,
#    'Longitude': 24.00604248046875,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8221549987793,
#    'Longitude': 24.006502151489258,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82785415649414,
#    'Longitude': 24.000293731689453,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82745361328125,
#    'Longitude': 24.00369644165039,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8101806640625,
#    'Longitude': 23.983928680419922,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80475997924805,
#    'Longitude': 23.98199462890625,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80392074584961,
#    'Longitude': 23.98271942138672,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.831031799316406,
#    'Longitude': 24.002273559570312,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80955123901367,
#    'Longitude': 23.994524002075195,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80816650390625,
#    'Longitude': 23.986549377441406,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80280303955078,
#    'Longitude': 23.988971710205078,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.829864501953125,
#    'Longitude': 23.99349021911621,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81065368652344,
#    'Longitude': 24.00184440612793,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.83245849609375,
#    'Longitude': 24.003202438354492,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.811119079589844,
#    'Longitude': 23.987491607666016,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82070541381836,
#    'Longitude': 24.01170539855957,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82284164428711,
#    'Longitude': 23.98957061767578,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81093978881836,
#    'Longitude': 23.990127563476562,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8111686706543,
#    'Longitude': 23.9879150390625,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.808876037597656,
#    'Longitude': 23.99580192565918,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80866241455078,
#    'Longitude': 23.99395751953125,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80654525756836,
#    'Longitude': 23.994159698486328,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80940246582031,
#    'Longitude': 23.989011764526367,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80628967285156,
#    'Longitude': 24.00352668762207,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80363082885742,
#    'Longitude': 23.984155654907227,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80307388305664,
#    'Longitude': 23.98464584350586,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82643127441406,
#    'Longitude': 24.000564575195312,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81392288208008,
#    'Longitude': 23.994300842285156,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80979537963867,
#    'Longitude': 24.00238037109375,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80922317504883,
#    'Longitude': 24.00112533569336,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.805320739746094,
#    'Longitude': 24.00250816345215,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80427932739258,
#    'Longitude': 24.00039291381836,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81836700439453,
#    'Longitude': 24.001012802124023,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80693054199219,
#    'Longitude': 23.999794006347656,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80910873413086,
#    'Longitude': 23.984172821044922,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.808349609375,
#    'Longitude': 23.984159469604492,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80995178222656,
#    'Longitude': 23.983736038208008,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80669021606445,
#    'Longitude': 23.9959774017334,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80473327636719,
#    'Longitude': 23.995189666748047,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81309127807617,
#    'Longitude': 23.998205184936523,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.830299377441406,
#    'Longitude': 24.013132095336914,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82954788208008,
#    'Longitude': 24.00922203063965,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80691146850586,
#    'Longitude': 23.9860897064209,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80634307861328,
#    'Longitude': 23.985578536987305,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80575180053711,
#    'Longitude': 23.985580444335938,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.803409576416016,
#    'Longitude': 23.981582641601562,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.814002990722656,
#    'Longitude': 23.992761611938477,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81564712524414,
#    'Longitude': 23.99532127380371,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.814273834228516,
#    'Longitude': 23.994619369506836,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8092041015625,
#    'Longitude': 23.993404388427734,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81133270263672,
#    'Longitude': 23.985239028930664,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.802608489990234,
#    'Longitude': 23.986778259277344,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80402374267578,
#    'Longitude': 23.987653732299805,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80084991455078,
#    'Longitude': 23.987916946411133,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82298278808594,
#    'Longitude': 23.995386123657227,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82738494873047,
#    'Longitude': 24.01790428161621,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.833003997802734,
#    'Longitude': 23.981731414794922,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.827056884765625,
#    'Longitude': 23.981639862060547,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.830596923828125,
#    'Longitude': 24.017864227294922,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82572937011719,
#    'Longitude': 24.010839462280273,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.815792083740234,
#    'Longitude': 24.00392723083496,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.823089599609375,
#    'Longitude': 24.008533477783203,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.810630798339844,
#    'Longitude': 24.008045196533203,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.83091735839844,
#    'Longitude': 24.011571884155273,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.830474853515625,
#    'Longitude': 24.009151458740234,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.83132553100586,
#    'Longitude': 24.00961685180664,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.829078674316406,
#    'Longitude': 24.00516700744629,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.828495025634766,
#    'Longitude': 24.004314422607422,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.803184509277344,
#    'Longitude': 23.991870880126953,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.803924560546875,
#    'Longitude': 23.991596221923828,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.802696228027344,
#    'Longitude': 23.981346130371094,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8051643371582,
#    'Longitude': 23.99056625366211,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80807113647461,
#    'Longitude': 24.016963958740234,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80751419067383,
#    'Longitude': 24.01451301574707,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80790710449219,
#    'Longitude': 24.0128173828125,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.806148529052734,
#    'Longitude': 24.001440048217773,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.830406188964844,
#    'Longitude': 23.99690818786621,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.83395767211914,
#    'Longitude': 24.005353927612305,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82896423339844,
#    'Longitude': 23.992660522460938,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.832923889160156,
#    'Longitude': 23.995479583740234,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82926940917969,
#    'Longitude': 23.97966766357422,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82478713989258,
#    'Longitude': 24.0074462890625,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.820716857910156,
#    'Longitude': 24.00107765197754,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.83415603637695,
#    'Longitude': 24.013944625854492,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80447006225586,
#    'Longitude': 23.985633850097656,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.804222106933594,
#    'Longitude': 23.995927810668945,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82843017578125,
#    'Longitude': 23.996292114257812,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8242073059082,
#    'Longitude': 23.990673065185547,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.826332092285156,
#    'Longitude': 23.99713134765625,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.83319091796875,
#    'Longitude': 23.99250030517578,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82561492919922,
#    'Longitude': 23.995845794677734,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8045654296875,
#    'Longitude': 24.004985809326172,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82748794555664,
#    'Longitude': 23.996492385864258,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.83359146118164,
#    'Longitude': 24.008167266845703,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.83368682861328,
#    'Longitude': 23.9996337890625,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.826908111572266,
#    'Longitude': 23.99323081970215,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.83401107788086,
#    'Longitude': 23.988388061523438,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81198501586914,
#    'Longitude': 23.996896743774414,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81210708618164,
#    'Longitude': 23.992528915405273,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.83017349243164,
#    'Longitude': 23.990137100219727,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.83146667480469,
#    'Longitude': 24.006650924682617,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80576705932617,
#    'Longitude': 24.016799926757812,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.829349517822266,
#    'Longitude': 23.99300765991211,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.806312561035156,
#    'Longitude': 24.017866134643555,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81654739379883,
#    'Longitude': 24.00713539123535,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.820491790771484,
#    'Longitude': 24.011171340942383,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.810420989990234,
#    'Longitude': 23.99557876586914,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82164001464844,
#    'Longitude': 24.00981903076172,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.813419342041016,
#    'Longitude': 24.016756057739258,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80498123168945,
#    'Longitude': 23.99295425415039,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.829444885253906,
#    'Longitude': 24.013002395629883,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81354904174805,
#    'Longitude': 24.01848793029785,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81875228881836,
#    'Longitude': 24.019289016723633,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82197952270508,
#    'Longitude': 24.000736236572266,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81376266479492,
#    'Longitude': 24.01558494567871,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.825260162353516,
#    'Longitude': 24.01369285583496,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.807796478271484,
#    'Longitude': 23.996074676513672,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80960464477539,
#    'Longitude': 23.996606826782227,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81707763671875,
#    'Longitude': 23.99768829345703,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80599594116211,
#    'Longitude': 23.9848575592041,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.806156158447266,
#    'Longitude': 23.98369598388672,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80536651611328,
#    'Longitude': 23.991958618164062,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80804443359375,
#    'Longitude': 24.0001277923584,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80488586425781,
#    'Longitude': 23.999853134155273,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80379867553711,
#    'Longitude': 24.004127502441406,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.805599212646484,
#    'Longitude': 24.003555297851562,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8324089050293,
#    'Longitude': 23.983274459838867,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.83137893676758,
#    'Longitude': 23.996789932250977,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80634689331055,
#    'Longitude': 23.982484817504883,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.807777404785156,
#    'Longitude': 23.993328094482422,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80948257446289,
#    'Longitude': 23.990966796875,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8037223815918,
#    'Longitude': 23.992794036865234,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.812007904052734,
#    'Longitude': 23.996885299682617,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80815505981445,
#    'Longitude': 24.005508422851562,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80402755737305,
#    'Longitude': 23.990345001220703,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.818153381347656,
#    'Longitude': 24.01400375366211,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80599594116211,
#    'Longitude': 23.990442276000977,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.800872802734375,
#    'Longitude': 23.984724044799805,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.801666259765625,
#    'Longitude': 23.99431610107422,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79604721069336,
#    'Longitude': 24.016281127929688,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.810489654541016,
#    'Longitude': 24.0045223236084,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81059265136719,
#    'Longitude': 24.003673553466797,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.83113098144531,
#    'Longitude': 24.009851455688477,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81242752075195,
#    'Longitude': 23.99416160583496,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.807498931884766,
#    'Longitude': 24.00609016418457,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80867004394531,
#    'Longitude': 24.003551483154297,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82249450683594,
#    'Longitude': 23.996931076049805,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.807125091552734,
#    'Longitude': 24.0068302154541,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80876922607422,
#    'Longitude': 24.008888244628906,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8098030090332,
#    'Longitude': 24.0025634765625,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.810447692871094,
#    'Longitude': 23.99576187133789,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80936050415039,
#    'Longitude': 23.991527557373047,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.827903747558594,
#    'Longitude': 24.009456634521484,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82875061035156,
#    'Longitude': 24.001739501953125,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8299560546875,
#    'Longitude': 24.003549575805664,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.815486907958984,
#    'Longitude': 23.997596740722656,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80642318725586,
#    'Longitude': 23.99950408935547,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80545425415039,
#    'Longitude': 23.999298095703125,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82465362548828,
#    'Longitude': 23.994359970092773,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81086730957031,
#    'Longitude': 23.98427963256836,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.814292907714844,
#    'Longitude': 24.01431655883789,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80330276489258,
#    'Longitude': 23.995203018188477,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80414581298828,
#    'Longitude': 24.002155303955078,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8021354675293,
#    'Longitude': 23.992603302001953,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80427932739258,
#    'Longitude': 24.000585556030273,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80536651611328,
#    'Longitude': 23.999971389770508,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80586242675781,
#    'Longitude': 24.00006866455078,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.804744720458984,
#    'Longitude': 23.98369789123535,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80492401123047,
#    'Longitude': 23.99344825744629,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.805763244628906,
#    'Longitude': 23.992855072021484,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.805206298828125,
#    'Longitude': 23.990018844604492,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.805389404296875,
#    'Longitude': 23.989154815673828,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82872772216797,
#    'Longitude': 23.988222122192383,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80583953857422,
#    'Longitude': 24.011049270629883,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80512237548828,
#    'Longitude': 24.009401321411133,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.805938720703125,
#    'Longitude': 24.009572982788086,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80585479736328,
#    'Longitude': 23.987422943115234,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80855941772461,
#    'Longitude': 24.007049560546875,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.810333251953125,
#    'Longitude': 24.017993927001953,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.797698974609375,
#    'Longitude': 24.016342163085938,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80940628051758,
#    'Longitude': 23.985719680786133,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8335075378418,
#    'Longitude': 24.001222610473633,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81101608276367,
#    'Longitude': 24.01305389404297,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82207489013672,
#    'Longitude': 24.012731552124023,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80130386352539,
#    'Longitude': 23.992727279663086,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.832157135009766,
#    'Longitude': 23.9778995513916,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.808773040771484,
#    'Longitude': 24.017166137695312,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8095817565918,
#    'Longitude': 24.005094528198242,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.83185577392578,
#    'Longitude': 23.977523803710938,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82904815673828,
#    'Longitude': 23.98222541809082,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80362319946289,
#    'Longitude': 24.008207321166992,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81283950805664,
#    'Longitude': 23.98857879638672,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80057907104492,
#    'Longitude': 23.990999221801758,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.812042236328125,
#    'Longitude': 24.012868881225586,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81245040893555,
#    'Longitude': 23.999835968017578,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81986618041992,
#    'Longitude': 24.01776885986328,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.822845458984375,
#    'Longitude': 24.0130615234375,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.807682037353516,
#    'Longitude': 24.006996154785156,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8148307800293,
#    'Longitude': 23.986648559570312,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80877685546875,
#    'Longitude': 24.004993438720703,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80284881591797,
#    'Longitude': 24.014673233032227,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80915069580078,
#    'Longitude': 24.000215530395508,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80995559692383,
#    'Longitude': 24.00030517578125,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80329895019531,
#    'Longitude': 24.012374877929688,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80363082885742,
#    'Longitude': 24.010297775268555,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8054084777832,
#    'Longitude': 24.007600784301758,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8204231262207,
#    'Longitude': 24.017383575439453,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81620407104492,
#    'Longitude': 23.997722625732422,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82094192504883,
#    'Longitude': 24.020124435424805,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81962966918945,
#    'Longitude': 24.019643783569336,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81318283081055,
#    'Longitude': 23.986345291137695,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.811363220214844,
#    'Longitude': 23.99360466003418,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82950210571289,
#    'Longitude': 24.00285530090332,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82852554321289,
#    'Longitude': 24.00299644470215,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.825469970703125,
#    'Longitude': 24.00809669494629,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82768249511719,
#    'Longitude': 24.00777244567871,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.828121185302734,
#    'Longitude': 24.006351470947266,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82440948486328,
#    'Longitude': 24.011280059814453,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80938720703125,
#    'Longitude': 24.006629943847656,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.805259704589844,
#    'Longitude': 24.00867462158203,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80562210083008,
#    'Longitude': 24.013578414916992,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.803977966308594,
#    'Longitude': 24.00591278076172,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.808738708496094,
#    'Longitude': 24.000823974609375,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80405044555664,
#    'Longitude': 23.98444938659668,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81134796142578,
#    'Longitude': 24.017507553100586,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.87010192871094,
#    'Longitude': 23.956928253173828,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8115234375,
#    'Longitude': 23.992372512817383,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8265266418457,
#    'Longitude': 23.989620208740234,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82463836669922,
#    'Longitude': 24.01380729675293,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8094482421875,
#    'Longitude': 24.01482391357422,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.825462341308594,
#    'Longitude': 23.99422836303711,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80901336669922,
#    'Longitude': 23.99642562866211,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80840301513672,
#    'Longitude': 23.991134643554688,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80612564086914,
#    'Longitude': 23.9840145111084,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80232620239258,
#    'Longitude': 23.995399475097656,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80480194091797,
#    'Longitude': 23.9947509765625,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80482482910156,
#    'Longitude': 23.99410629272461,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.800384521484375,
#    'Longitude': 23.988109588623047,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79970932006836,
#    'Longitude': 24.01556968688965,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8088493347168,
#    'Longitude': 24.00713539123535,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82526397705078,
#    'Longitude': 24.01155662536621,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81767654418945,
#    'Longitude': 24.013076782226562,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79767608642578,
#    'Longitude': 24.011402130126953,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.83027648925781,
#    'Longitude': 23.98185157775879,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80769729614258,
#    'Longitude': 23.984142303466797,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81124496459961,
#    'Longitude': 23.99595069885254,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82804870605469,
#    'Longitude': 23.990459442138672,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.835906982421875,
#    'Longitude': 23.999765396118164,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.818397521972656,
#    'Longitude': 24.00103759765625,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.816551208496094,
#    'Longitude': 24.01136016845703,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81718826293945,
#    'Longitude': 24.012187957763672,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82855224609375,
#    'Longitude': 24.015573501586914,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8257942199707,
#    'Longitude': 24.013399124145508,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80068588256836,
#    'Longitude': 23.98921012878418,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8017578125,
#    'Longitude': 23.98940086364746,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.82090759277344,
#    'Longitude': 24.017974853515625,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.83040237426758,
#    'Longitude': 24.007740020751953,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.792152404785156,
#    'Longitude': 24.0706729888916,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.793792724609375,
#    'Longitude': 24.06732177734375,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79530334472656,
#    'Longitude': 24.064191818237305,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79443359375,
#    'Longitude': 24.066909790039062,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79383087158203,
#    'Longitude': 24.06334114074707,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.805240631103516,
#    'Longitude': 24.01886558532715,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.798377990722656,
#    'Longitude': 24.01849937438965,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.791961669921875,
#    'Longitude': 24.057405471801758,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.796321868896484,
#    'Longitude': 24.022384643554688,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.817596435546875,
#    'Longitude': 24.057697296142578,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80375289916992,
#    'Longitude': 24.069095611572266,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.788352966308594,
#    'Longitude': 24.060129165649414,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80802536010742,
#    'Longitude': 24.055259704589844,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79603576660156,
#    'Longitude': 24.05564308166504,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79336929321289,
#    'Longitude': 24.06053352355957,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.792327880859375,
#    'Longitude': 24.061708450317383,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.798973083496094,
#    'Longitude': 24.056150436401367,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80195236206055,
#    'Longitude': 24.066038131713867,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.790706634521484,
#    'Longitude': 24.07217025756836,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78779983520508,
#    'Longitude': 24.021818161010742,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79783248901367,
#    'Longitude': 24.039470672607422,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.796730041503906,
#    'Longitude': 24.054792404174805,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78889083862305,
#    'Longitude': 24.059707641601562,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81238555908203,
#    'Longitude': 24.036787033081055,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79730224609375,
#    'Longitude': 24.05707550048828,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78974151611328,
#    'Longitude': 24.01644515991211,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79334259033203,
#    'Longitude': 24.017412185668945,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79155349731445,
#    'Longitude': 24.071374893188477,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.7919921875,
#    'Longitude': 24.06207847595215,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79459762573242,
#    'Longitude': 24.062454223632812,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.794151306152344,
#    'Longitude': 24.06497573852539,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79170608520508,
#    'Longitude': 24.069351196289062,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80066680908203,
#    'Longitude': 24.048555374145508,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79398727416992,
#    'Longitude': 24.06869888305664,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.7996940612793,
#    'Longitude': 24.056432723999023,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79945373535156,
#    'Longitude': 24.05550765991211,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79907989501953,
#    'Longitude': 24.05220603942871,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80050277709961,
#    'Longitude': 24.054977416992188,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79637908935547,
#    'Longitude': 24.058910369873047,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79901123046875,
#    'Longitude': 24.059921264648438,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.799354553222656,
#    'Longitude': 24.058950424194336,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79715347290039,
#    'Longitude': 24.05517578125,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79651641845703,
#    'Longitude': 24.05624771118164,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.801605224609375,
#    'Longitude': 24.051128387451172,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79546356201172,
#    'Longitude': 24.04558563232422,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80141830444336,
#    'Longitude': 24.049177169799805,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.7975959777832,
#    'Longitude': 24.05634880065918,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79563522338867,
#    'Longitude': 24.043874740600586,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79682540893555,
#    'Longitude': 24.03963279724121,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.797401428222656,
#    'Longitude': 24.040088653564453,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79298400878906,
#    'Longitude': 24.053041458129883,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.792236328125,
#    'Longitude': 24.05377769470215,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.789703369140625,
#    'Longitude': 24.055158615112305,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78560256958008,
#    'Longitude': 24.055585861206055,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.7864990234375,
#    'Longitude': 24.055185317993164,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.790836334228516,
#    'Longitude': 24.066551208496094,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.781890869140625,
#    'Longitude': 24.066389083862305,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.785762786865234,
#    'Longitude': 24.02366065979004,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.787567138671875,
#    'Longitude': 24.06332015991211,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78734588623047,
#    'Longitude': 24.064851760864258,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.786685943603516,
#    'Longitude': 24.060773849487305,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78633499145508,
#    'Longitude': 24.0600528717041,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.789859771728516,
#    'Longitude': 24.061359405517578,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.818443298339844,
#    'Longitude': 24.05731964111328,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.816017150878906,
#    'Longitude': 24.051013946533203,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79819107055664,
#    'Longitude': 24.061735153198242,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.796016693115234,
#    'Longitude': 24.057947158813477,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78963851928711,
#    'Longitude': 24.064016342163086,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.7951545715332,
#    'Longitude': 24.0626220703125,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78636932373047,
#    'Longitude': 24.06731605529785,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79832458496094,
#    'Longitude': 24.04166603088379,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79990005493164,
#    'Longitude': 24.019573211669922,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79747009277344,
#    'Longitude': 24.029539108276367,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79977035522461,
#    'Longitude': 24.028987884521484,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79799270629883,
#    'Longitude': 24.023332595825195,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79811477661133,
#    'Longitude': 24.02582359313965,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79677963256836,
#    'Longitude': 24.017963409423828,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8162727355957,
#    'Longitude': 24.054275512695312,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80381774902344,
#    'Longitude': 24.072254180908203,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.802093505859375,
#    'Longitude': 24.02975082397461,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78917694091797,
#    'Longitude': 24.06110954284668,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81474304199219,
#    'Longitude': 24.054304122924805,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.789791107177734,
#    'Longitude': 24.068347930908203,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79010772705078,
#    'Longitude': 24.065622329711914,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79775619506836,
#    'Longitude': 24.043201446533203,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.798336029052734,
#    'Longitude': 24.044803619384766,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.799957275390625,
#    'Longitude': 24.043981552124023,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.799964904785156,
#    'Longitude': 24.043180465698242,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78443908691406,
#    'Longitude': 24.0571231842041,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81550598144531,
#    'Longitude': 24.029916763305664,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81716537475586,
#    'Longitude': 24.029521942138672,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.814659118652344,
#    'Longitude': 24.034936904907227,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.818485260009766,
#    'Longitude': 24.027549743652344,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8178825378418,
#    'Longitude': 24.026716232299805,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81415939331055,
#    'Longitude': 24.042404174804688,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81685256958008,
#    'Longitude': 24.041906356811523,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81256103515625,
#    'Longitude': 24.035600662231445,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80157470703125,
#    'Longitude': 24.05473518371582,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81779861450195,
#    'Longitude': 24.057741165161133,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81843566894531,
#    'Longitude': 24.057565689086914,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.798187255859375,
#    'Longitude': 24.05355453491211,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.811859130859375,
#    'Longitude': 24.038379669189453,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.817378997802734,
#    'Longitude': 24.041440963745117,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80030822753906,
#    'Longitude': 24.05278205871582,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.8006591796875,
#    'Longitude': 24.05205535888672,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.799747467041016,
#    'Longitude': 24.057153701782227,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79844284057617,
#    'Longitude': 24.0516300201416,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79902648925781,
#    'Longitude': 24.050138473510742,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.798580169677734,
#    'Longitude': 24.05071258544922,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79692840576172,
#    'Longitude': 24.057344436645508,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.7827033996582,
#    'Longitude': 24.054611206054688,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78374099731445,
#    'Longitude': 24.058374404907227,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79644012451172,
#    'Longitude': 24.066574096679688,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78849792480469,
#    'Longitude': 24.054471969604492,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.783443450927734,
#    'Longitude': 24.06537437438965,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.795955657958984,
#    'Longitude': 24.048301696777344,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.796932220458984,
#    'Longitude': 24.046661376953125,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79365921020508,
#    'Longitude': 24.064226150512695,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79261016845703,
#    'Longitude': 24.060317993164062,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78467559814453,
#    'Longitude': 24.069618225097656,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79805374145508,
#    'Longitude': 24.028564453125,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78611373901367,
#    'Longitude': 24.055578231811523,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79647445678711,
#    'Longitude': 24.061256408691406,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79546356201172,
#    'Longitude': 24.06035614013672,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.790531158447266,
#    'Longitude': 24.06986427307129,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.788509368896484,
#    'Longitude': 24.061447143554688,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78811264038086,
#    'Longitude': 24.065532684326172,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.789005279541016,
#    'Longitude': 24.06717872619629,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78954315185547,
#    'Longitude': 24.06511116027832,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79779815673828,
#    'Longitude': 24.06841468811035,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.797264099121094,
#    'Longitude': 24.06698989868164,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79721450805664,
#    'Longitude': 24.066753387451172,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79126739501953,
#    'Longitude': 24.07047462463379,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80126953125,
#    'Longitude': 24.056882858276367,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.7952995300293,
#    'Longitude': 24.065040588378906,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.796356201171875,
#    'Longitude': 24.06495475769043,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79335403442383,
#    'Longitude': 24.062135696411133,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79624557495117,
#    'Longitude': 24.063196182250977,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.799407958984375,
#    'Longitude': 24.017545700073242,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78329849243164,
#    'Longitude': 24.064132690429688,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.81132507324219,
#    'Longitude': 24.044309616088867,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79582977294922,
#    'Longitude': 24.043378829956055,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79287338256836,
#    'Longitude': 24.06644058227539,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79732131958008,
#    'Longitude': 24.067888259887695,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79574203491211,
#    'Longitude': 24.06778907775879,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79347229003906,
#    'Longitude': 24.0692081451416,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79283905029297,
#    'Longitude': 24.069677352905273,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.7929573059082,
#    'Longitude': 24.068571090698242,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78847885131836,
#    'Longitude': 24.01987648010254,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78168487548828,
#    'Longitude': 24.020729064941406,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78154754638672,
#    'Longitude': 24.022993087768555,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.799739837646484,
#    'Longitude': 24.018754959106445,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79655075073242,
#    'Longitude': 24.02825164794922,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78334426879883,
#    'Longitude': 24.01779556274414,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.797061920166016,
#    'Longitude': 24.068588256835938,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79688262939453,
#    'Longitude': 24.067846298217773,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79775619506836,
#    'Longitude': 24.066591262817383,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79755401611328,
#    'Longitude': 24.045589447021484,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79503631591797,
#    'Longitude': 24.04477882385254,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.794857025146484,
#    'Longitude': 24.043672561645508,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.798828125,
#    'Longitude': 24.045351028442383,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.7878532409668,
#    'Longitude': 24.057390213012695,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78493881225586,
#    'Longitude': 24.06771469116211,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78414535522461,
#    'Longitude': 24.067792892456055,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.783790588378906,
#    'Longitude': 24.068256378173828,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78337097167969,
#    'Longitude': 24.068134307861328,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78168869018555,
#    'Longitude': 24.063949584960938,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.783878326416016,
#    'Longitude': 24.055015563964844,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78311538696289,
#    'Longitude': 24.054004669189453,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79721450805664,
#    'Longitude': 24.06182861328125,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.786956787109375,
#    'Longitude': 24.062631607055664,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.80762481689453,
#    'Longitude': 24.039772033691406,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79528045654297,
#    'Longitude': 24.065898895263672,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78894805908203,
#    'Longitude': 24.057435989379883,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.788185119628906,
#    'Longitude': 24.053682327270508,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78248977661133,
#    'Longitude': 24.052589416503906,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.790828704833984,
#    'Longitude': 24.016891479492188,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.7890739440918,
#    'Longitude': 24.01987648010254,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78779220581055,
#    'Longitude': 24.020992279052734,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.786563873291016,
#    'Longitude': 24.019540786743164,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.786006927490234,
#    'Longitude': 24.019248962402344,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.783504486083984,
#    'Longitude': 24.063579559326172,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78422927856445,
#    'Longitude': 24.06698226928711,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.7823371887207,
#    'Longitude': 24.06541633605957,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78849792480469,
#    'Longitude': 24.05726432800293,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.7833251953125,
#    'Longitude': 24.05988121032715,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79867172241211,
#    'Longitude': 24.048460006713867,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.800472259521484,
#    'Longitude': 24.048398971557617,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.7997932434082,
#    'Longitude': 24.050153732299805,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79969024658203,
#    'Longitude': 24.052095413208008,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.79563903808594,
#    'Longitude': 24.05162239074707,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.78718566894531,
#    'Longitude': 24.060819625854492,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.785945892333984,
#    'Longitude': 24.069616317749023,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.782798767089844,
#    'Longitude': 24.068323135375977,
#    'Type': 'RegularContainer'},
#   {'Latitude': 49.781333923339844,
# ...
#     {'Latitude': 49.81325149536133, 'Longitude': 23.870941162109375},
#     {'Latitude': 49.81306457519531, 'Longitude': 23.869766235351562},
#     {'Latitude': 49.81288146972656, 'Longitude': 23.86860466003418},
#     {'Latitude': 49.8128547668457, 'Longitude': 23.86842918395996},
#     {'Latitude': 49.812400817871094, 'Longitude': 23.865373611450195},
#     {'Latitude': 49.81238555908203, 'Longitude': 23.865249633789062},
#     {'Latitude': 49.81232452392578, 'Longitude': 23.8648738861084},
#     {'Latitude': 49.81224060058594, 'Longitude': 23.86427116394043},
#     {'Latitude': 49.8121452331543, 'Longitude': 23.863632202148438},
#     {'Latitude': 49.81207275390625, 'Longitude': 23.86309814453125},
#     {'Latitude': 49.81187438964844, 'Longitude': 23.861865997314453},
#     {'Latitude': 49.811683654785156, 'Longitude': 23.86066246032715},
#     {'Latitude': 49.811161041259766, 'Longitude': 23.857227325439453},
#     {'Latitude': 49.81106948852539, 'Longitude': 23.856645584106445},
#     {'Latitude': 49.810890197753906, 'Longitude': 23.855449676513672},
#     {'Latitude': 49.8104362487793, 'Longitude': 23.85260772705078},
#     {'Latitude': 49.810302734375, 'Longitude': 23.851762771606445},
#     {'Latitude': 49.80936050415039, 'Longitude': 23.84557342529297},
#     {'Latitude': 49.80902862548828, 'Longitude': 23.843475341796875},
#     {'Latitude': 49.808902740478516, 'Longitude': 23.842668533325195},
#     {'Latitude': 49.808074951171875, 'Longitude': 23.837631225585938},
#     {'Latitude': 49.807960510253906, 'Longitude': 23.836912155151367},
#     {'Latitude': 49.80794143676758, 'Longitude': 23.83679962158203},
#     {'Latitude': 49.80712127685547, 'Longitude': 23.83145523071289},
#     {'Latitude': 49.80657196044922, 'Longitude': 23.82802391052246},
#     {'Latitude': 49.806236267089844, 'Longitude': 23.825899124145508},
#     {'Latitude': 49.80544662475586, 'Longitude': 23.820892333984375},
#     {'Latitude': 49.80513381958008, 'Longitude': 23.81883430480957},
#     {'Latitude': 49.804813385009766, 'Longitude': 23.816770553588867},
#     {'Latitude': 49.80480194091797, 'Longitude': 23.816673278808594},
#     {'Latitude': 49.80464172363281, 'Longitude': 23.815683364868164},
#     {'Latitude': 49.804378509521484, 'Longitude': 23.813976287841797},
#     {'Latitude': 49.80412673950195, 'Longitude': 23.812191009521484},
#     {'Latitude': 49.80290222167969, 'Longitude': 23.804553985595703},
#     {'Latitude': 49.80274963378906, 'Longitude': 23.8035831451416},
#     {'Latitude': 49.80270004272461, 'Longitude': 23.803274154663086},
#     {'Latitude': 49.802520751953125, 'Longitude': 23.80217742919922},
#     {'Latitude': 49.80238342285156, 'Longitude': 23.801280975341797},
#     {'Latitude': 49.801944732666016, 'Longitude': 23.79850196838379},
#     {'Latitude': 49.800933837890625, 'Longitude': 23.79189682006836},
#     {'Latitude': 49.800167083740234, 'Longitude': 23.786991119384766},
#     {'Latitude': 49.799896240234375, 'Longitude': 23.78527069091797},
#     {'Latitude': 49.79976272583008, 'Longitude': 23.784364700317383},
#     {'Latitude': 49.79958724975586, 'Longitude': 23.783294677734375},
#     {'Latitude': 49.79932403564453, 'Longitude': 23.781635284423828},
#     {'Latitude': 49.7990608215332, 'Longitude': 23.779956817626953},
#     {'Latitude': 49.79895782470703, 'Longitude': 23.7792911529541},
#     {'Latitude': 49.798683166503906, 'Longitude': 23.77754783630371},
#     {'Latitude': 49.79853057861328, 'Longitude': 23.77663230895996},
#     {'Latitude': 49.79836654663086, 'Longitude': 23.775577545166016},
#     {'Latitude': 49.797515869140625, 'Longitude': 23.770042419433594},
#     {'Latitude': 49.79719924926758, 'Longitude': 23.768009185791016},
#     {'Latitude': 49.79285430908203, 'Longitude': 23.73979949951172},
#     {'Latitude': 49.789398193359375, 'Longitude': 23.715293884277344},
#     {'Latitude': 49.788028717041016, 'Longitude': 23.704153060913086},
#     {'Latitude': 49.78767776489258, 'Longitude': 23.701547622680664},
#     {'Latitude': 49.78630828857422, 'Longitude': 23.69698715209961},
#     {'Latitude': 49.77511978149414, 'Longitude': 23.674171447753906},
#     {'Latitude': 49.774681091308594, 'Longitude': 23.673070907592773},
#     {'Latitude': 49.769649505615234, 'Longitude': 23.662334442138672},
#     {'Latitude': 49.763954162597656, 'Longitude': 23.646892547607422},
#     {'Latitude': 49.763912200927734, 'Longitude': 23.64600372314453},
#     {'Latitude': 49.76395797729492, 'Longitude': 23.643657684326172},
#     {'Latitude': 49.76393508911133, 'Longitude': 23.64325523376465},
#     {'Latitude': 49.76385498046875, 'Longitude': 23.642318725585938},
#     {'Latitude': 49.763763427734375, 'Longitude': 23.641822814941406},
#     {'Latitude': 49.763423919677734, 'Longitude': 23.640785217285156},
#     {'Latitude': 49.76494216918945, 'Longitude': 23.624725341796875},
#     {'Latitude': 49.767967224121094, 'Longitude': 23.611906051635742},
#     {'Latitude': 49.784423828125, 'Longitude': 23.580869674682617},
#     {'Latitude': 49.790592193603516, 'Longitude': 23.541175842285156},
#     {'Latitude': 49.792049407958984, 'Longitude': 23.515003204345703},
#     {'Latitude': 49.79231643676758, 'Longitude': 23.512353897094727},
#     {'Latitude': 49.79200744628906, 'Longitude': 23.495037078857422},
#     {'Latitude': 49.791297912597656, 'Longitude': 23.479867935180664},
#     {'Latitude': 49.79127502441406, 'Longitude': 23.479633331298828},
#     {'Latitude': 49.79114532470703, 'Longitude': 23.478418350219727},
#     {'Latitude': 49.79054641723633, 'Longitude': 23.475074768066406},
#     {'Latitude': 49.788909912109375, 'Longitude': 23.449970245361328},
#     {'Latitude': 49.78852081298828, 'Longitude': 23.42340087890625},
#     {'Latitude': 49.78901672363281, 'Longitude': 23.417606353759766},
#     {'Latitude': 49.7905158996582, 'Longitude': 23.411771774291992},
#     {'Latitude': 49.789432525634766, 'Longitude': 23.412113189697266},
#     {'Latitude': 49.78920364379883, 'Longitude': 23.412395477294922},
#     {'Latitude': 49.788997650146484, 'Longitude': 23.415361404418945},
#     {'Latitude': 49.78599166870117, 'Longitude': 23.414833068847656},
#     {'Latitude': 49.788997650146484, 'Longitude': 23.415361404418945},
#     {'Latitude': 49.78901672363281, 'Longitude': 23.417606353759766},
#     {'Latitude': 49.78852081298828, 'Longitude': 23.42340087890625},
#     {'Latitude': 49.788909912109375, 'Longitude': 23.449970245361328},
#     {'Latitude': 49.79054641723633, 'Longitude': 23.475074768066406},
#     {'Latitude': 49.79114532470703, 'Longitude': 23.478418350219727},
#     {'Latitude': 49.79127502441406, 'Longitude': 23.479633331298828},
#     {'Latitude': 49.791297912597656, 'Longitude': 23.479867935180664},
#     {'Latitude': 49.79200744628906, 'Longitude': 23.495037078857422},
#     {'Latitude': 49.79231643676758, 'Longitude': 23.512353897094727},
#     {'Latitude': 49.792049407958984, 'Longitude': 23.515003204345703},
#     {'Latitude': 49.790592193603516, 'Longitude': 23.541175842285156},
#     {'Latitude': 49.784423828125, 'Longitude': 23.580869674682617},
#     {'Latitude': 49.767967224121094, 'Longitude': 23.611906051635742},
#     {'Latitude': 49.76494216918945, 'Longitude': 23.624725341796875},
#     {'Latitude': 49.763423919677734, 'Longitude': 23.640785217285156},
#     {'Latitude': 49.76323318481445, 'Longitude': 23.641965866088867},
#     {'Latitude': 49.763221740722656, 'Longitude': 23.642576217651367},
#     {'Latitude': 49.763282775878906, 'Longitude': 23.643310546875},
#     {'Latitude': 49.76333236694336, 'Longitude': 23.64381217956543},
#     {'Latitude': 49.7636833190918, 'Longitude': 23.645923614501953},
#     {'Latitude': 49.76386642456055, 'Longitude': 23.646913528442383},
#     {'Latitude': 49.769649505615234, 'Longitude': 23.662334442138672},
#     {'Latitude': 49.774681091308594, 'Longitude': 23.673070907592773},
#     {'Latitude': 49.77511978149414, 'Longitude': 23.674171447753906},
#     {'Latitude': 49.78630828857422, 'Longitude': 23.69698715209961},
#     {'Latitude': 49.78767776489258, 'Longitude': 23.701547622680664},
#     {'Latitude': 49.788028717041016, 'Longitude': 23.704153060913086},
#     {'Latitude': 49.789398193359375, 'Longitude': 23.715293884277344},
#     {'Latitude': 49.79285430908203, 'Longitude': 23.73979949951172},
#     {'Latitude': 49.79719924926758, 'Longitude': 23.768009185791016},
#     {'Latitude': 49.797515869140625, 'Longitude': 23.770042419433594},
#     {'Latitude': 49.79836654663086, 'Longitude': 23.775577545166016},
#     {'Latitude': 49.79853057861328, 'Longitude': 23.77663230895996},
#     {'Latitude': 49.798683166503906, 'Longitude': 23.77754783630371},
#     {'Latitude': 49.79895782470703, 'Longitude': 23.7792911529541},
#     {'Latitude': 49.7990608215332, 'Longitude': 23.779956817626953},
#     {'Latitude': 49.79932403564453, 'Longitude': 23.781635284423828},
#     {'Latitude': 49.79958724975586, 'Longitude': 23.783294677734375},
#     {'Latitude': 49.79976272583008, 'Longitude': 23.784364700317383},
#     {'Latitude': 49.799896240234375, 'Longitude': 23.78527069091797},
#     {'Latitude': 49.800167083740234, 'Longitude': 23.786991119384766},
#     {'Latitude': 49.800933837890625, 'Longitude': 23.79189682006836},
#     {'Latitude': 49.801944732666016, 'Longitude': 23.79850196838379},
#     {'Latitude': 49.80238342285156, 'Longitude': 23.801280975341797},
#     {'Latitude': 49.802520751953125, 'Longitude': 23.80217742919922},
#     {'Latitude': 49.80270004272461, 'Longitude': 23.803274154663086},
#     {'Latitude': 49.80274963378906, 'Longitude': 23.8035831451416},
#     {'Latitude': 49.80290222167969, 'Longitude': 23.804553985595703},
#     {'Latitude': 49.80412673950195, 'Longitude': 23.812191009521484},
#     {'Latitude': 49.804378509521484, 'Longitude': 23.813976287841797},
#     {'Latitude': 49.80464172363281, 'Longitude': 23.815683364868164},
#     {'Latitude': 49.80480194091797, 'Longitude': 23.816673278808594},
#     {'Latitude': 49.804813385009766, 'Longitude': 23.816770553588867},
#     {'Latitude': 49.80513381958008, 'Longitude': 23.81883430480957},
#     {'Latitude': 49.80544662475586, 'Longitude': 23.820892333984375},
#     {'Latitude': 49.806236267089844, 'Longitude': 23.825899124145508},
#     {'Latitude': 49.80657196044922, 'Longitude': 23.82802391052246},
#     {'Latitude': 49.80712127685547, 'Longitude': 23.83145523071289},
#     {'Latitude': 49.80794143676758, 'Longitude': 23.83679962158203},
#     {'Latitude': 49.807960510253906, 'Longitude': 23.836912155151367},
#     {'Latitude': 49.808074951171875, 'Longitude': 23.837631225585938},
#     {'Latitude': 49.808902740478516, 'Longitude': 23.842668533325195},
#     {'Latitude': 49.80902862548828, 'Longitude': 23.843475341796875},
#     {'Latitude': 49.80936050415039, 'Longitude': 23.84557342529297},
#     {'Latitude': 49.810302734375, 'Longitude': 23.851762771606445},
#     {'Latitude': 49.8104362487793, 'Longitude': 23.85260772705078},
#     {'Latitude': 49.810890197753906, 'Longitude': 23.855449676513672},
#     {'Latitude': 49.81106948852539, 'Longitude': 23.856645584106445},
#     {'Latitude': 49.811161041259766, 'Longitude': 23.857227325439453},
#     {'Latitude': 49.811683654785156, 'Longitude': 23.86066246032715},
#     {'Latitude': 49.81187438964844, 'Longitude': 23.861865997314453},
#     {'Latitude': 49.81207275390625, 'Longitude': 23.86309814453125},
#     {'Latitude': 49.8121452331543, 'Longitude': 23.863632202148438},
#     {'Latitude': 49.81224060058594, 'Longitude': 23.86427116394043},
#     {'Latitude': 49.81232452392578, 'Longitude': 23.8648738861084},
#     {'Latitude': 49.81238555908203, 'Longitude': 23.865249633789062},
#     {'Latitude': 49.812400817871094, 'Longitude': 23.865373611450195},
#     {'Latitude': 49.8128547668457, 'Longitude': 23.86842918395996},
#     {'Latitude': 49.81288146972656, 'Longitude': 23.86860466003418},
#     {'Latitude': 49.81306457519531, 'Longitude': 23.869766235351562},
#     {'Latitude': 49.81325149536133, 'Longitude': 23.870941162109375},
#     {'Latitude': 49.81336975097656, 'Longitude': 23.871715545654297},
#     {'Latitude': 49.81352233886719, 'Longitude': 23.87270736694336},
#     {'Latitude': 49.81367874145508, 'Longitude': 23.873743057250977},
#     {'Latitude': 49.813804626464844, 'Longitude': 23.874549865722656},
#     {'Latitude': 49.81405258178711, 'Longitude': 23.876178741455078},
#     {'Latitude': 49.81462097167969, 'Longitude': 23.879810333251953},
#     {'Latitude': 49.814735412597656, 'Longitude': 23.880544662475586},
#     {'Latitude': 49.8153190612793, 'Longitude': 23.884471893310547},
#     {'Latitude': 49.81547927856445, 'Longitude': 23.885499954223633},
#     {'Latitude': 49.81647872924805, 'Longitude': 23.892309188842773},
#     {'Latitude': 49.816585540771484, 'Longitude': 23.893041610717773},
#     {'Latitude': 49.81667709350586, 'Longitude': 23.893672943115234},
#     {'Latitude': 49.816707611083984, 'Longitude': 23.893890380859375},
#     {'Latitude': 49.816890716552734, 'Longitude': 23.89493179321289},
#     {'Latitude': 49.81709671020508, 'Longitude': 23.896093368530273},
#     {'Latitude': 49.81722640991211, 'Longitude': 23.896915435791016},
#     {'Latitude': 49.81747055053711, 'Longitude': 23.897979736328125},
#     {'Latitude': 49.817726135253906, 'Longitude': 23.89908790588379},
#     {'Latitude': 49.81831359863281, 'Longitude': 23.901456832885742},
#     {'Latitude': 49.818538665771484, 'Longitude': 23.902379989624023},
#     {'Latitude': 49.81880569458008, 'Longitude': 23.903562545776367},
#     {'Latitude': 49.81904983520508, 'Longitude': 23.904754638671875},
#     {'Latitude': 49.81935119628906, 'Longitude': 23.90612030029297},
#     {'Latitude': 49.81980514526367, 'Longitude': 23.908525466918945},
#     {'Latitude': 49.82040786743164, 'Longitude': 23.91268539428711},
#     {'Latitude': 49.820335388183594, 'Longitude': 23.91289710998535},
#     {'Latitude': 49.820430755615234, 'Longitude': 23.91327667236328},
#     {'Latitude': 49.820499420166016, 'Longitude': 23.9133358001709},
#     {'Latitude': 49.82156753540039, 'Longitude': 23.919288635253906},
#     {'Latitude': 49.82247543334961, 'Longitude': 23.924285888671875},
#     {'Latitude': 49.823448181152344, 'Longitude': 23.92953109741211},
#     {'Latitude': 49.82380676269531, 'Longitude': 23.93149185180664},
#     {'Latitude': 49.82401657104492, 'Longitude': 23.93256378173828},
#     {'Latitude': 49.82436752319336, 'Longitude': 23.93438148498535},
#     {'Latitude': 49.824520111083984, 'Longitude': 23.93488311767578},
#     {'Latitude': 49.82610321044922, 'Longitude': 23.943267822265625},
#     {'Latitude': 49.82640075683594, 'Longitude': 23.944883346557617},
#     {'Latitude': 49.82682418823242, 'Longitude': 23.94761085510254},
#     {'Latitude': 49.826908111572266, 'Longitude': 23.948057174682617},
#     {'Latitude': 49.82781219482422, 'Longitude': 23.952476501464844},
#     {'Latitude': 49.82798767089844, 'Longitude': 23.95351791381836},
#     {'Latitude': 49.82817840576172, 'Longitude': 23.954565048217773},
#     {'Latitude': 49.828407287597656, 'Longitude': 23.955787658691406},
#     ...],
#    'Truck': {'Latitude': 49.80594253540039,
#     'Longitude': 23.988576889038086,
#     'Type': 'BigTruck'}}],
#  'Search': 'TABU',
#  'TotalDistance': 5351.4911,
#  'TotalFuel': 1337.872775,
#  'TotalTime': 34.00637333333333,
#  'Trucks': [{'Latitude': 49.80594253540039,
#    'Longitude': 23.988576889038086,
#    'Type': 'BigTruck'},
#   {'Latitude': 49.80594253540039,
#    'Longitude': 23.988576889038086,
#    'Type': 'BigTruck'},
#   {'Latitude': 49.80594253540039,
#    'Longitude': 23.988576889038086,
#    'Type': 'BigTruck'},
#   {'Latitude': 49.80594253540039,
#    'Longitude': 23.988576889038086,
#    'Type': 'BigTruck'},
#   {'Latitude': 49.80594253540039,
#    'Longitude': 23.988576889038086,
#    'Type': 'BigTruck'},
#   {'Latitude': 49.80594253540039,
#    'Longitude': 23.988576889038086,
#    'Type': 'BigTruck'},
#   {'Latitude': 49.80594253540039,
#    'Longitude': 23.988576889038086,
#    'Type': 'BigTruck'},
#   {'Latitude': 49.80594253540039,
#    'Longitude': 23.988576889038086,
#    'Type': 'BigTruck'},
#   {'Latitude': 49.80594253540039,
#    'Longitude': 23.988576889038086,
#    'Type': 'BigTruck'},
#   {'Latitude': 49.80594253540039,
#    'Longitude': 23.988576889038086,
#    'Type': 'BigTruck'}],
#  'UnusedTrucksCount': 0}
